# %% [markdown]
# ## DataSet Creator
# ### __Some Background__
# - The data is collected from 2 different datasets
# - The COVID +ve xrays are from https://github.com/ieee8023/covid-chestxray-dataset
# - The COVID -ve xrays are actually the normal samples of human lungs collected from kaggle : https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia
#
# - We need to extract the data accordingly

# %% [markdown]
# ### DATA PREP :: 1 - For COVID +ve Samples

# %%
import pandas as pd

# %%
file_path = "./covid-chestxray-dataset-master/covid-chestxray-dataset-master/metadata.csv"
image_path = "./covid-chestxray-dataset-master/covid-chestxray-dataset-master/images/"

# %%
## We need to select particular images using the csv file
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#   patientid  offset sex   age                   finding RT_PCR_positive  \
# 0         2     0.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 1         2     3.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 2         2     5.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 3         2     6.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 4         4     0.0   F  52.0  Pneumonia/Viral/COVID-19               Y
#
#   survival intubated intubation_present went_icu  ...              date  \
# 0        Y         N                  N        N  ...  January 22, 2020
# 1        Y         N                  N        N  ...  January 25, 2020
# 2        Y         N                  N        N  ...  January 27, 2020
# 3        Y         N                  N        N  ...  January 28, 2020
# 4      NaN         N                  N        N  ...  January 25, 2020
#
#                                             location  folder  \
# 0        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 1        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 2        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 3        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 4  Changhua Christian Hospital, Changhua City, Ta...  images
#
#                                             filename                   doi  \
# 0  auntminnie-a-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 1  auntminnie-b-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 2  auntminnie-c-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 3  auntminnie-d-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 4                              nejmc2001573_f1a.jpeg  10.1056/NEJMc2001573
#
#                                                  url  license  \
# 0  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 1  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 2  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 3  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 4  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
#
#                                       clinical_notes other_notes Unnamed: 29
# 0  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 1  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 2  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 3  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 4   diffuse infiltrates in the bilateral lower lungs         NaN         NaN
#
# [5 rows x 30 columns]

# %%
## We will move the COVID +ve images in the Covid dir inside the Dataset folder
import os

# Creating the Covid folder
target_dir = "Dataset/Covid"

if not os.path.exists(target_dir):
    os.mkdir(target_dir)
    print("Covid folder created")
# Out:
# Covid folder created

# %%
## Total Covid images available
cnt = 0

for (i,row) in df.iterrows():
    
    if row["finding"] == "Pneumonia/Viral/COVID-19":
        cnt += 1
        
print(cnt)
# Out:
# 584

# %% [markdown]
#  - Not all Xrays are of the same orientation
#  - We only want those Xrays, which have Front-view or posteroanterior (PA) view
#  - Thus, that info is stored in another column called "view"

# %%
## Total Covid images available with PA view
cnt = 0

for (i,row) in df.iterrows():
    
    if row["finding"] == "Pneumonia/Viral/COVID-19" and row["view"] == "PA":
        cnt += 1
        
print(cnt)
# Out:
# 196

# %%
## Transferring the images to the Covid folder

import shutil

## Total Covid images available with PA view
cnt = 0

for (i,row) in df.iterrows():
    
    if row["finding"] == "Pneumonia/Viral/COVID-19" and row["view"] == "PA":
        
        file_name = row["filename"]
        
        # src
        img_src = os.path.join(image_path, file_name)
        
        # dst
        img_dst = os.path.join(target_dir, file_name)
        
        # Transferring a copy of the image
        shutil.copy2(img_src, img_dst)
        
        # Logs
        print("Image Moved Successfully", cnt)
        
        cnt += 1
# Out:
# Image Moved Successfully 0
# Image Moved Successfully 1
# Image Moved Successfully 2
# Image Moved Successfully 3
# Image Moved Successfully 4
# Image Moved Successfully 5
# Image Moved Successfully 6
# Image Moved Successfully 7
# Image Moved Successfully 8
# Image Moved Successfully 9
# Image Moved Successfully 10
# Image Moved Successfully 11
# Image Moved Successfully 12
# Image Moved Successfully 13
# Image Moved Successfully 14
# Image Moved Successfully 15
# Image Moved Successfully 16
# Image Moved Successfully 17
# Image Moved Successfully 18
# Image Moved Successfully 19
# Image Moved Successfully 20
# Image Moved Successfully 21
# Image Moved Successfully 22
# Image Moved Successfully 23
# Image Moved Successfully 24
# Image Moved Successfully 25
# Image Moved Successfully 26
# Image Moved Successfully 27
# Image Moved Successfully 28
# Image Moved Successfully 29
# Image Moved Successfully 30
# Image Moved Successfully 31
# Image Moved Successfully 32
# Image Moved Successfully 33
# Image Moved Successfully 34
# Image Moved Successfully 35
# Image Moved Successfully 36
# Image Moved Successfully 37
# Image Moved Successfully 38
# Image Moved Successfully 39
# Image Moved Successfully 40
# Image Moved Successfully 41
# Image Moved Successfully 42
# Image Moved Successfully 43
# Image Moved Successfully 44
# Image Moved Successfully 45
# Image Moved Successfully 46
# Image Moved Successfully 47
# Image Moved Successfully 48
# Image Moved Successfully 49
# Image Moved Successfully 50
# Image Moved Successfully 51
# Image Moved Successfully 52
# Image Moved Successfully 53
# Image Moved Successfully 54
# Image Moved Successfully 55
# Image Moved Successfully 56
# Image Moved Successfully 57
# Image Moved Successfully 58
# Image Moved Successfully 59
# Image Moved Successfully 60
# Image Moved Successfully 61
# Image Moved Successfully 62
# Image Moved Successfully 63
# Image Moved Successfully 64
# Image Moved Successfully 65
# Image Moved Successfully 66
# Image Moved Successfully 67
# Image Moved Successfully 68
# Image Moved Successfully 69
# Image Moved Successfully 70
# Image Moved Successfully 71
# Image Moved Successfully 72
# Image Moved Successfully 73
# Image Moved Successfully 74
# Image Moved Successfully 75
# Image Moved Successfully 76
# Image Moved Successfully 77
# Image Moved Successfully 78
# Image Moved Successfully 79
# Image Moved Successfully 80
# Image Moved Successfully 81
# Image Moved Successfully 82
# Image Moved Successfully 83
# Image Moved Successfully 84
# Image Moved Successfully 85
# Image Moved Successfully 86
# Image Moved Successfully 87
# Image Moved Successfully 88
# Image Moved Successfully 89
# Image Moved Successfully 90
# Image Moved Successfully 91
# Image Moved Successfully 92
# Image Moved Successfully 93
# Image Moved Successfully 94
# Image Moved Successfully 95
# Image Moved Successfully 96
# Image Moved Successfully 97
# Image Moved Successfully 98
# Image Moved Successfully 99
# Image Moved Successfully 100
# Image Moved Successfully 101
# Image Moved Successfully 102
# Image Moved Successfully 103
# Image Moved Successfully 104
# Image Moved Successfully 105
# Image Moved Successfully 106
# Image Moved Successfully 107
# Image Moved Successfully 108
# Image Moved Successfully 109
# Image Moved Successfully 110
# Image Moved Successfully 111
# Image Moved Successfully 112
# Image Moved Successfully 113
# Image Moved Successfully 114
# Image Moved Successfully 115
# Image Moved Successfully 116
# Image Moved Successfully 117
# Image Moved Successfully 118
# Image Moved Successfully 119
# Image Moved Successfully 120
# Image Moved Successfully 121
# Image Moved Successfully 122
# Image Moved Successfully 123
# Image Moved Successfully 124
# Image Moved Successfully 125
# Image Moved Successfully 126
# Image Moved Successfully 127
# Image Moved Successfully 128
# Image Moved Successfully 129
# Image Moved Successfully 130
# Image Moved Successfully 131
# Image Moved Successfully 132
# Image Moved Successfully 133
# Image Moved Successfully 134
# Image Moved Successfully 135
# Image Moved Successfully 136
# Image Moved Successfully 137
# Image Moved Successfully 138
# Image Moved Successfully 139
# Image Moved Successfully 140
# Image Moved Successfully 141
# Image Moved Successfully 142
# Image Moved Successfully 143
# Image Moved Successfully 144
# Image Moved Successfully 145
# Image Moved Successfully 146
# Image Moved Successfully 147
# Image Moved Successfully 148
# Image Moved Successfully 149
# Image Moved Successfully 150
# Image Moved Successfully 151
# Image Moved Successfully 152
# Image Moved Successfully 153
# Image Moved Successfully 154
# Image Moved Successfully 155
# Image Moved Successfully 156
# Image Moved Successfully 157
# Image Moved Successfully 158
# Image Moved Successfully 159
# Image Moved Successfully 160
# Image Moved Successfully 161
# Image Moved Successfully 162
# Image Moved Successfully 163
# Image Moved Successfully 164
# Image Moved Successfully 165
# Image Moved Successfully 166
# Image Moved Successfully 167
# Image Moved Successfully 168
# Image Moved Successfully 169
# Image Moved Successfully 170
# Image Moved Successfully 171
# Image Moved Successfully 172
# Image Moved Successfully 173
# Image Moved Successfully 174
# Image Moved Successfully 175
# Image Moved Successfully 176
# Image Moved Successfully 177
# Image Moved Successfully 178
# Image Moved Successfully 179
# Image Moved Successfully 180
# Image Moved Successfully 181
# Image Moved Successfully 182
# Image Moved Successfully 183
# Image Moved Successfully 184
# Image Moved Successfully 185
# Image Moved Successfully 186
# Image Moved Successfully 187
# Image Moved Successfully 188
# Image Moved Successfully 189
# Image Moved Successfully 190
# Image Moved Successfully 191
# Image Moved Successfully 192
# Image Moved Successfully 193
# Image Moved Successfully 194
# Image Moved Successfully 195

# %% [markdown]
# ## DATA PREP :: 2 - For COVID -ve/ Normal Samples

# %%
# Creating the Normal folder
target_dir_normal = "Dataset/Normal"

if not os.path.exists(target_dir_normal):
    os.mkdir(target_dir_normal)
    print("Normal folder created")
# Out:
# Normal folder created

# %%
## The dataset from kaggle has much more images than the Covid +ve samples
## Therefore, we will select some random images so as to keep the ratios equal

import random

kaggle_file_path = "./archive/chest_xray/train/NORMAL/"

# %%
## Images in the Kaggle's Normal folder
image_names = os.listdir(kaggle_file_path)

# %%
len(image_names)
# Out:
# 1341

# %%
## Randomly shuffling the images
random.shuffle(image_names)

# %%
## Moving only 196 images
## Note : The paths are shuffled

for i in range(196):
    
    img_name = image_names[i]
    
    # src
    img_src = os.path.join(kaggle_file_path, img_name)
    
    # dst
    img_dst = os.path.join(target_dir_normal, img_name)
    
    # Transferring a copy of the image
    shutil.copy2(img_src, img_dst)

    # Logs
    print("Image Moved Successfully", i)
# Out:
# Image Moved Successfully 0
# Image Moved Successfully 1
# Image Moved Successfully 2
# Image Moved Successfully 3
# Image Moved Successfully 4
# Image Moved Successfully 5
# Image Moved Successfully 6
# Image Moved Successfully 7
# Image Moved Successfully 8
# Image Moved Successfully 9
# Image Moved Successfully 10
# Image Moved Successfully 11
# Image Moved Successfully 12
# Image Moved Successfully 13
# Image Moved Successfully 14
# Image Moved Successfully 15
# Image Moved Successfully 16
# Image Moved Successfully 17
# Image Moved Successfully 18
# Image Moved Successfully 19
# Image Moved Successfully 20
# Image Moved Successfully 21
# Image Moved Successfully 22
# Image Moved Successfully 23
# Image Moved Successfully 24
# Image Moved Successfully 25
# Image Moved Successfully 26
# Image Moved Successfully 27
# Image Moved Successfully 28
# Image Moved Successfully 29
# Image Moved Successfully 30
# Image Moved Successfully 31
# Image Moved Successfully 32
# Image Moved Successfully 33
# Image Moved Successfully 34
# Image Moved Successfully 35
# Image Moved Successfully 36
# Image Moved Successfully 37
# Image Moved Successfully 38
# Image Moved Successfully 39
# Image Moved Successfully 40
# Image Moved Successfully 41
# Image Moved Successfully 42
# Image Moved Successfully 43
# Image Moved Successfully 44
# Image Moved Successfully 45
# Image Moved Successfully 46
# Image Moved Successfully 47
# Image Moved Successfully 48
# Image Moved Successfully 49
# Image Moved Successfully 50
# Image Moved Successfully 51
# Image Moved Successfully 52
# Image Moved Successfully 53
# Image Moved Successfully 54
# Image Moved Successfully 55
# Image Moved Successfully 56
# Image Moved Successfully 57
# Image Moved Successfully 58
# Image Moved Successfully 59
# Image Moved Successfully 60
# Image Moved Successfully 61
# Image Moved Successfully 62
# Image Moved Successfully 63
# Image Moved Successfully 64
# Image Moved Successfully 65
# Image Moved Successfully 66
# Image Moved Successfully 67
# Image Moved Successfully 68
# Image Moved Successfully 69
# Image Moved Successfully 70
# Image Moved Successfully 71
# Image Moved Successfully 72
# Image Moved Successfully 73
# Image Moved Successfully 74
# Image Moved Successfully 75
# Image Moved Successfully 76
# Image Moved Successfully 77
# Image Moved Successfully 78
# Image Moved Successfully 79
# Image Moved Successfully 80
# Image Moved Successfully 81
# Image Moved Successfully 82
# Image Moved Successfully 83
# Image Moved Successfully 84
# Image Moved Successfully 85
# Image Moved Successfully 86
# Image Moved Successfully 87
# Image Moved Successfully 88
# Image Moved Successfully 89
# Image Moved Successfully 90
# Image Moved Successfully 91
# Image Moved Successfully 92
# Image Moved Successfully 93
# Image Moved Successfully 94
# Image Moved Successfully 95
# Image Moved Successfully 96
# Image Moved Successfully 97
# Image Moved Successfully 98
# Image Moved Successfully 99
# Image Moved Successfully 100
# Image Moved Successfully 101
# Image Moved Successfully 102
# Image Moved Successfully 103
# Image Moved Successfully 104
# Image Moved Successfully 105
# Image Moved Successfully 106
# Image Moved Successfully 107
# Image Moved Successfully 108
# Image Moved Successfully 109
# Image Moved Successfully 110
# Image Moved Successfully 111
# Image Moved Successfully 112
# Image Moved Successfully 113
# Image Moved Successfully 114
# Image Moved Successfully 115
# Image Moved Successfully 116
# Image Moved Successfully 117
# Image Moved Successfully 118
# Image Moved Successfully 119
# Image Moved Successfully 120
# Image Moved Successfully 121
# Image Moved Successfully 122
# Image Moved Successfully 123
# Image Moved Successfully 124
# Image Moved Successfully 125
# Image Moved Successfully 126
# Image Moved Successfully 127
# Image Moved Successfully 128
# Image Moved Successfully 129
# Image Moved Successfully 130
# Image Moved Successfully 131
# Image Moved Successfully 132
# Image Moved Successfully 133
# Image Moved Successfully 134
# Image Moved Successfully 135
# Image Moved Successfully 136
# Image Moved Successfully 137
# Image Moved Successfully 138
# Image Moved Successfully 139
# Image Moved Successfully 140
# Image Moved Successfully 141
# Image Moved Successfully 142
# Image Moved Successfully 143
# Image Moved Successfully 144
# Image Moved Successfully 145
# Image Moved Successfully 146
# Image Moved Successfully 147
# Image Moved Successfully 148
# Image Moved Successfully 149
# Image Moved Successfully 150
# Image Moved Successfully 151
# Image Moved Successfully 152
# Image Moved Successfully 153
# Image Moved Successfully 154
# Image Moved Successfully 155
# Image Moved Successfully 156
# Image Moved Successfully 157
# Image Moved Successfully 158
# Image Moved Successfully 159
# Image Moved Successfully 160
# Image Moved Successfully 161
# Image Moved Successfully 162
# Image Moved Successfully 163
# Image Moved Successfully 164
# Image Moved Successfully 165
# Image Moved Successfully 166
# Image Moved Successfully 167
# Image Moved Successfully 168
# Image Moved Successfully 169
# Image Moved Successfully 170
# Image Moved Successfully 171
# Image Moved Successfully 172
# Image Moved Successfully 173
# Image Moved Successfully 174
# Image Moved Successfully 175
# Image Moved Successfully 176
# Image Moved Successfully 177
# Image Moved Successfully 178
# Image Moved Successfully 179
# Image Moved Successfully 180
# Image Moved Successfully 181
# Image Moved Successfully 182
# Image Moved Successfully 183
# Image Moved Successfully 184
# Image Moved Successfully 185
# Image Moved Successfully 186
# Image Moved Successfully 187
# Image Moved Successfully 188
# Image Moved Successfully 189
# Image Moved Successfully 190
# Image Moved Successfully 191
# Image Moved Successfully 192
# Image Moved Successfully 193
# Image Moved Successfully 194
# Image Moved Successfully 195
